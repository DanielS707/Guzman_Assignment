# %% [markdown]
# Create EDA using the data and make your model to predict RTLMP from the data

# %% [markdown]
# **In the data file timeseries_data.xlsx, you can find following timeseries (hourly):**
#
# RTLoad: ERCOT real-time hourly actual load
# WIND_RTI: ERCOT real-time hourly wind generation
# GENERATION_SOLAR_RT: ERCOT real-time solar generation
# RTLMP: ERCOT North hub real-time price

# %% [markdown]
# **Requirements:**
#
# Create Exploratory Data Analysis (EDA)
# Create forecast model to predict RTLMP (Real-Time Locational Marginal Prices)

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# %matplotlib inline
#pip install openpyxl

# %%
df3 = pd.read_excel('D:/Git_Desk/data_works/Guzman Project/Assignment 3 - timeseries_data.xlsx')
#df3 = pd.read_excel('C:/Users/DanielS/Desktop/GitHub_Clone/data_works/Guzman Project/Assignment 3 - timeseries_data.xlsx')
df = df3.copy()
df
# Out:
#                  DATETIME  HB_NORTH (RTLMP)  ERCOT (WIND_RTI)  \
# 0     2017-01-01 01:00:00           23.3575           2155.31
# 1     2017-01-01 02:00:00           21.4650           2313.81
# 2     2017-01-01 03:00:00           20.7350           2587.68
# 3     2017-01-01 04:00:00           20.2700           2748.65
# 4     2017-01-01 05:00:00           20.1200           2757.49
# ...                   ...               ...               ...
# 14982 2018-09-17 08:00:00           20.8600           3195.52
# 14983 2018-09-17 09:00:00           22.7675           2605.50
# 14984 2018-09-17 10:00:00           31.0600           2034.80
# 14985 2018-09-17 11:00:00           29.6700               NaN
# 14986 2018-09-17 12:00:00           33.6607               NaN
#
#        ERCOT (GENERATION_SOLAR_RT)  ERCOT (RTLOAD)  HOURENDING  MARKETDAY  \
# 0                             0.00    29485.791355           1 2017-01-01
# 1                             0.00    28911.565913           2 2017-01-01
# 2                             0.00    28238.258175           3 2017-01-01
# 3                             0.00    27821.000513           4 2017-01-01
# 4                             0.00    27646.942413           5 2017-01-01
# ...                            ...             ...         ...        ...
# 14982                         2.04    41902.240000           8 2018-09-17
# 14983                       111.59    43014.370000           9 2018-09-17
# 14984                       261.65    45782.550000          10 2018-09-17
# 14985                       464.88    49431.130000          11 2018-09-17
# 14986                          NaN    52347.250000          12 2018-09-17
#
#       PEAKTYPE      MONTH  YEAR
# 0      OFFPEAK    JANUARY  2017
# 1      OFFPEAK    JANUARY  2017
# 2      OFFPEAK    JANUARY  2017
# 3      OFFPEAK    JANUARY  2017
# 4      OFFPEAK    JANUARY  2017
# ...        ...        ...   ...
# 14982   WDPEAK  SEPTEMBER  2018
# 14983   WDPEAK  SEPTEMBER  2018
# 14984   WDPEAK  SEPTEMBER  2018
# 14985   WDPEAK  SEPTEMBER  2018
# 14986   WDPEAK  SEPTEMBER  2018
#
# [14987 rows x 10 columns]

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
missing_ob = df.isnull().sum()/ len(df) * 100 

print(missing_ob)
# Out:
# DATETIME                       0.000000
# HB_NORTH (RTLMP)               0.000000
# ERCOT (WIND_RTI)               0.033362
# ERCOT (GENERATION_SOLAR_RT)    0.026690
# ERCOT (RTLOAD)                 0.000000
# HOURENDING                     0.000000
# MARKETDAY                      0.000000
# PEAKTYPE                       0.000000
# MONTH                          0.000000
# YEAR                           0.000000
# dtype: float64

# %% [markdown]
# All categories have acceptable missing portion.

# %%
# Handle missing values
df = df.dropna() #6 of N/A vlaue are dropped.

# %%
#data cleaning
df.iloc[:,1:5].duplicated().sum()
df.describe()
# Out:
#        HB_NORTH (RTLMP)  ERCOT (WIND_RTI)  ERCOT (GENERATION_SOLAR_RT)  \
# count      14981.000000      14981.000000                 14981.000000
# mean          25.768281       7532.053149                   291.997647
# std           46.370881       3992.742693                   370.929008
# min          -17.860000         54.440000                     0.000000
# 25%           18.042500       4134.730000                     0.000000
# 50%           20.057500       7281.370000                    22.150000
# 75%           25.030000      10851.640000                   608.660000
# max         2809.357500      20350.400000                  1257.540000
#
#        ERCOT (RTLOAD)    HOURENDING          YEAR
# count    14981.000000  14981.000000  14981.000000
# mean     42372.917557     12.498765   2017.415460
# std       9874.696215      6.921451      0.492818
# min      25566.511248      1.000000   2017.000000
# 25%      35432.588663      7.000000   2017.000000
# 50%      39935.131628     12.000000   2017.000000
# 75%      47871.380668     18.000000   2018.000000
# max      73264.662123     24.000000   2018.000000

# %%
fig,ax = plt.subplots(figsize = (16, 5))
ax.plot(df['DATETIME'], df['HB_NORTH (RTLMP)'])
ax.set_title('RTLMP: ERCOT North hub real-time price')
# Out:
# Text(0.5, 1.0, 'RTLMP: ERCOT North hub real-time price')

# %%
#drop outliter
df = df[df['HB_NORTH (RTLMP)'] <= 500]
df.sort_values(by="HB_NORTH (RTLMP)", ascending=False)
# Out:
#                  DATETIME  HB_NORTH (RTLMP)  ERCOT (WIND_RTI)  \
# 13623 2018-07-22 17:00:00          494.7975           3019.56
# 312   2017-01-14 01:00:00          482.9050           3393.45
# 3326  2017-05-19 16:00:00          452.2725           6048.78
# 13765 2018-07-28 15:00:00          446.6000           2487.60
# 12493 2018-06-05 15:00:00          444.9850           2178.80
# ...                   ...               ...               ...
# 2255  2017-04-05 01:00:00           -9.6625          11972.23
# 218   2017-01-10 03:00:00          -11.4800          11570.82
# 2673  2017-04-22 11:00:00          -12.5300          11554.00
# 217   2017-01-10 02:00:00          -13.6075          11832.67
# 3421  2017-05-23 15:00:00          -17.8600          10029.13
#
#        ERCOT (GENERATION_SOLAR_RT)  ERCOT (RTLOAD)  HOURENDING  MARKETDAY  \
# 13623                      1133.62    70945.990785          17 2018-07-22
# 312                           0.11    33336.327325           1 2017-01-14
# 3326                        658.84    53999.100555          16 2017-05-19
# 13765                      1210.72    65040.478428          15 2018-07-28
# 12493                      1218.70    63904.550605          15 2018-06-05
# ...                            ...             ...         ...        ...
# 2255                          0.00    32575.858775           1 2017-04-05
# 218                           0.11    28449.908768           3 2017-01-10
# 2673                        187.24    35664.608470          11 2017-04-22
# 217                           0.11    28994.028000           2 2017-01-10
# 3421                        290.82    45378.964325          15 2017-05-23
#
#       PEAKTYPE    MONTH  YEAR
# 13623   WEPEAK     JULY  2018
# 312    OFFPEAK  JANUARY  2017
# 3326    WDPEAK      MAY  2017
# 13765   WEPEAK     JULY  2018
# 12493   WDPEAK     JUNE  2018
# ...        ...      ...   ...
# 2255   OFFPEAK    APRIL  2017
# 218    OFFPEAK  JANUARY  2017
# 2673    WEPEAK    APRIL  2017
# 217    OFFPEAK  JANUARY  2017
# 3421    WDPEAK      MAY  2017
#
# [14960 rows x 10 columns]

# %%
df.rename(columns={'HB_NORTH (RTLMP)': 'RTLMP', 
                        'ERCOT (WIND_RTI)': 'WIND_RTI', 
                        'ERCOT (GENERATION_SOLAR_RT)': 'GENERATION_SOLAR_RT', 
                        'ERCOT (RTLOAD)': 'RTLOAD'},  inplace=True)
df.head()
# Out:
#              DATETIME    RTLMP  WIND_RTI  GENERATION_SOLAR_RT        RTLOAD  \
# 0 2017-01-01 01:00:00  23.3575   2155.31                  0.0  29485.791355
# 1 2017-01-01 02:00:00  21.4650   2313.81                  0.0  28911.565913
# 2 2017-01-01 03:00:00  20.7350   2587.68                  0.0  28238.258175
# 3 2017-01-01 04:00:00  20.2700   2748.65                  0.0  27821.000513
# 4 2017-01-01 05:00:00  20.1200   2757.49                  0.0  27646.942413
#
#    HOURENDING  MARKETDAY PEAKTYPE    MONTH  YEAR
# 0           1 2017-01-01  OFFPEAK  JANUARY  2017
# 1           2 2017-01-01  OFFPEAK  JANUARY  2017
# 2           3 2017-01-01  OFFPEAK  JANUARY  2017
# 3           4 2017-01-01  OFFPEAK  JANUARY  2017
# 4           5 2017-01-01  OFFPEAK  JANUARY  2017

# %%
def plot_series(df=None, column=None, series=pd.Series([]), 
                label=None, ylabel=None, title=None, start=0, end=None):
    sns.set()
    fig, ax = plt.subplots(figsize=(30, 12))
    ax.set_xlabel('Time', fontsize=16)
    if column:
        ax.plot(df[column][start:end], label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if series.any():
        ax.plot(series, label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if label:
        ax.legend(fontsize=16)
    if title:
        ax.set_title(title, fontsize=24)
    ax.grid(True)
    return ax
# Out:
# C:\Users\suisx\AppData\Local\Temp\ipykernel_7652\1031602474.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   def plot_series(df=None, column=None, series=pd.Series([]),

# %%
ax = plot_series(df=df, column='RTLMP', ylabel='Timestamp',
                 title='detailed plot to check the RTLMP vs Timestamp in any period of time', end=10000)
plt.show()

# %% [markdown]
# # Improvement of Prediction and analysis

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#turn datetime to a continuous variable:
df['Timestamp'] = (df['DATETIME'] - pd.Timestamp("2017-01-01 00:00:00")) // pd.Timedelta('1h')
df.drop(['DATETIME', 'MARKETDAY'], axis=1, inplace=True)
df.tail(5)
# Out:
#          RTLMP  WIND_RTI  GENERATION_SOLAR_RT    RTLOAD  HOURENDING PEAKTYPE  \
# 14980  20.3950   3094.87                 0.00  37923.34           6  OFFPEAK
# 14981  20.8800   3325.27                 0.00  40936.18           7   WDPEAK
# 14982  20.8600   3195.52                 2.04  41902.24           8   WDPEAK
# 14983  22.7675   2605.50               111.59  43014.37           9   WDPEAK
# 14984  31.0600   2034.80               261.65  45782.55          10   WDPEAK
#
#            MONTH  YEAR  Timestamp
# 14980  SEPTEMBER  2018      14982
# 14981  SEPTEMBER  2018      14983
# 14982  SEPTEMBER  2018      14984
# 14983  SEPTEMBER  2018      14985
# 14984  SEPTEMBER  2018      14986

# %%
from sklearn import preprocessing

#replace the Peaktype by value
df['PEAKTYPE'] = df['PEAKTYPE'].replace({'OFFPEAK': 0, 'WEPEAK': 2, 'WDPEAK': 4})
# rescale the data for the better predictions:
drop_list=["RTLMP", "HOURENDING", "MONTH", "YEAR"]

#spliting data prepare
y = pd.DataFrame(df["RTLMP"])
X = df.drop([col for col in drop_list if col in df], axis=1)

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
def split_train_test(X, y, test_size):
    # Determine the index at which to split the data
    split_index = int(len(X) * (1 - test_size))
    
    # Split the data into training and test sets
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]
    
    return X_train, X_test, y_train, y_test

# Split the X and y data into train and test sets
X_train, X_test, y_train, y_test = split_train_test(X, y, test_size=0.05)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

unique_classes = np.unique(y_train)
num_classes = len(unique_classes)
print(f'Number of classes: {num_classes}')
# Out:
# X_train shape: (14212, 5)
# X_test shape: (748, 5)
# y_train shape: (14212, 1)
# y_test shape: (748, 1)
# Number of classes: 7101

# %%
# Use transformed data with a model:
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

scaler = preprocessing.MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
ridge = Ridge().fit(X_train_scaled, y_train)
X_test_scaled = scaler.transform(X_test)
ridge.score(X_test_scaled, y_test)
# Out:
# 0.2619291281366203

# %%
import numpy as np
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)
print(f'Number of classes: {num_classes}')
# Out:
# Number of classes: 7101

# %%
#MinMax Scaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from keras.utils import to_categorical

# number of classes:
#num_classes = 6227
num_classes = 7101

# one-hot vectors
y_train_categorical = to_categorical(y_train, num_classes=num_classes)
y_test_categorical = to_categorical(y_test, num_classes=num_classes)

model = Sequential()

# Input layer
model.add(Dense(32, activation='relu', input_shape=(5,)))

# Hidden layers
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output layer
model.add(Dense(num_classes, activation='softmax'))

# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01),  # note the change to `learning_rate` from `lr`
              metrics=['accuracy'])

# fit the model to the training data
model.fit(X_train_scaled, y_train_categorical, epochs=50, batch_size=32)

# evaluate the model on the test data
score = model.evaluate(X_test_scaled, y_test_categorical)

print(score)
# Out:
# Epoch 1/50
# 445/445 [==============================] - 4s 6ms/step - loss: 8.4710 - accuracy: 0.1268
# Epoch 2/50
# 445/445 [==============================] - 3s 6ms/step - loss: 4.1190 - accuracy: 0.1264
# Epoch 3/50
# 445/445 [==============================] - 3s 6ms/step - loss: 3.5280 - accuracy: 0.1238
# Epoch 4/50
# 445/445 [==============================] - 3s 6ms/step - loss: 3.4457 - accuracy: 0.1215
# Epoch 5/50
# 445/445 [==============================] - 2s 4ms/step - loss: 3.4008 - accuracy: 0.1260
# Epoch 6/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.3592 - accuracy: 0.1283
# Epoch 7/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.3107 - accuracy: 0.1307
# Epoch 8/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.2504 - accuracy: 0.1347
# Epoch 9/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.1857 - accuracy: 0.1390
# Epoch 10/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.1148 - accuracy: 0.1456
# Epoch 11/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.0450 - accuracy: 0.1502
# Epoch 12/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.9831 - accuracy: 0.1568
# Epoch 13/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.9251 - accuracy: 0.1691
# Epoch 14/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.8802 - accuracy: 0.1749
# Epoch 15/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.8433 - accuracy: 0.1817
# Epoch 16/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.8139 - accuracy: 0.1848
# Epoch 17/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7921 - accuracy: 0.1886
# Epoch 18/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7765 - accuracy: 0.1891
# Epoch 19/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7604 - accuracy: 0.1889
# Epoch 20/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7472 - accuracy: 0.1929
# Epoch 21/50
# 322/445 [====================>.........] - ETA: 0s - loss: 2.7411 - accuracy: 0.1947

# %%
# predict with my model
y_pred = model.predict(X_test_scaled)

# turn categroy to labels
y_pred = np.argmax(y_pred, axis=1)

# plot
plt.figure(figsize=(14,5))

# plt y_test
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, color='green', label='y_test')

# plt y_pred
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred, color='blue', label='predictions')

plt.legend()
plt.title('MLP Model prediction with MinMax Scaler')
plt.show()
# Out:
# 24/24 [==============================] - 0s 3ms/step

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 346.28972757352943

# %%
# Add a constant to the features
X_train_scaled_sm = sm.add_constant(X_train_scaled)
X_test_scaled_sm = sm.add_constant(X_test_scaled)

# Train the model
model = sm.OLS(y_train, X_train_scaled_sm)
results = model.fit()

# use the results object to make predictions
y_pred = results.predict(X_test_scaled_sm)

# Plotting the results
plt.figure(figsize=(14,5))

# Plotting the y_train
#plt.plot(range(len(y_train)), y_train, color='blue', label='y_train')

# Plotting the y_test
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, color='green', label='y_test')

# Plotting the predictions
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred, color='blue', label='predictions')

plt.legend()
plt.title('OLS Model prediction with MinMax Scaler')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 300.3546022247436

# %%
# standardize by X data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)
X_test_scaled
# Out:
#      WIND_RTI  GENERATION_SOLAR_RT    RTLOAD  PEAKTYPE  Timestamp
# 0    0.072430            -0.786106  0.061176 -1.280515   1.734427
# 1    0.103283            -0.786106  0.007730 -1.280515   1.734670
# 2    0.030798            -0.786106  0.083961 -1.280515   1.734913
# 3   -0.001440            -0.786106  0.288231  0.980612   1.735157
# 4   -0.073561            -0.690816  0.353793  0.980612   1.735400
# ..        ...                  ...       ...       ...        ...
# 743 -1.137123            -0.786106 -0.415193 -1.280515   1.916037
# 744 -1.079274            -0.786106 -0.104655  0.980612   1.916280
# 745 -1.111852            -0.780508 -0.005082  0.980612   1.916523
# 746 -1.259994            -0.479844  0.109547  0.980612   1.916767
# 747 -1.403286            -0.067999  0.394867  0.980612   1.917010
#
# [748 rows x 5 columns]

# %%
import numpy as np
unique_classes = np.unique(y_train)
num_classes = len(unique_classes)
print(f'Number of classes: {num_classes}')
# Out:
# Number of classes: 7101

# %%
# number of classes:
num_classes = 7101

# one-hot vectors
y_train_categorical = to_categorical(y_train, num_classes=num_classes)
y_test_categorical = to_categorical(y_test, num_classes=num_classes)

model = Sequential()

# Input layer
model.add(Dense(32, activation='relu', input_shape=(5,)))

# Hidden layers
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output layer
model.add(Dense(num_classes, activation='softmax'))

# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01),  # note the change to `learning_rate` from `lr`
              metrics=['accuracy'])

# fit the model to the training data
model.fit(X_train_scaled, y_train_categorical, epochs=50, batch_size=32)

# evaluate the model on the test data
score = model.evaluate(X_test_scaled, y_test_categorical)

print(score)
# Out:
# Epoch 1/50
# 445/445 [==============================] - 3s 6ms/step - loss: 7.7483 - accuracy: 0.1278
# Epoch 2/50
# 445/445 [==============================] - 3s 7ms/step - loss: 3.7672 - accuracy: 0.1350
# Epoch 3/50
# 445/445 [==============================] - 6s 13ms/step - loss: 3.3011 - accuracy: 0.1476
# Epoch 4/50
# 445/445 [==============================] - 6s 13ms/step - loss: 3.1068 - accuracy: 0.1661
# Epoch 5/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.9779 - accuracy: 0.1786
# Epoch 6/50
# 445/445 [==============================] - 4s 10ms/step - loss: 2.8926 - accuracy: 0.1881
# Epoch 7/50
# 445/445 [==============================] - 4s 8ms/step - loss: 2.8340 - accuracy: 0.1935
# Epoch 8/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7877 - accuracy: 0.1991
# Epoch 9/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7578 - accuracy: 0.1979
# Epoch 10/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7293 - accuracy: 0.2044
# Epoch 11/50
# 445/445 [==============================] - 4s 8ms/step - loss: 2.7145 - accuracy: 0.1991
# Epoch 12/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6986 - accuracy: 0.2019
# Epoch 13/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6871 - accuracy: 0.2022
# Epoch 14/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6772 - accuracy: 0.2076
# Epoch 15/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6681 - accuracy: 0.2038
# Epoch 16/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6584 - accuracy: 0.2086
# Epoch 17/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6551 - accuracy: 0.2071
# Epoch 18/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6459 - accuracy: 0.2157
# Epoch 19/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6425 - accuracy: 0.2061
# Epoch 20/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6363 - accuracy: 0.2090
# Epoch 21/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6295 - accuracy: 0.2140
# Epoch 22/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6255 - accuracy: 0.2146
# Epoch 23/50
# 445/445 [==============================] - 4s 9ms/step - loss: 2.6202 - accuracy: 0.2064
# Epoch 24/50
# 445/445 [==============================] - 6s 14ms/step - loss: 2.6147 - accuracy: 0.2129
# Epoch 25/50
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6124 - accuracy: 0.2099
# Epoch 26/50
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6060 - accuracy: 0.2183
# Epoch 27/50
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6037 - accuracy: 0.2168
# Epoch 28/50
# 445/445 [==============================] - 6s 14ms/step - loss: 2.5996 - accuracy: 0.2182
# Epoch 29/50
# 445/445 [==============================] - 5s 11ms/step - loss: 2.5969 - accuracy: 0.2128
# Epoch 30/50
# 445/445 [==============================] - 3s 7ms/step - loss: 2.5912 - accuracy: 0.2153
# Epoch 31/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.5890 - accuracy: 0.2212
# Epoch 32/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5843 - accuracy: 0.2202
# Epoch 33/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5794 - accuracy: 0.2209
# Epoch 34/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5763 - accuracy: 0.2177
# Epoch 35/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5748 - accuracy: 0.2186
# Epoch 36/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5724 - accuracy: 0.2190
# Epoch 37/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5664 - accuracy: 0.2243
# Epoch 38/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5628 - accuracy: 0.2219
# Epoch 39/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5584 - accuracy: 0.2240
# Epoch 40/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5568 - accuracy: 0.2200
# Epoch 41/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5520 - accuracy: 0.2235
# Epoch 42/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5491 - accuracy: 0.2221
# Epoch 43/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5467 - accuracy: 0.2207
# Epoch 44/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5441 - accuracy: 0.2233
# Epoch 45/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5396 - accuracy: 0.2269
# Epoch 46/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5384 - accuracy: 0.2250
# Epoch 47/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5377 - accuracy: 0.2244
# Epoch 48/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5328 - accuracy: 0.2249
# Epoch 49/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5285 - accuracy: 0.2297
# Epoch 50/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5252 - accuracy: 0.2281
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6706 - accuracy: 0.1725
# [2.6706387996673584, 0.1724599003791809]

# %%
# predict using my model
y_pred = model.predict(X_test_scaled)

# turn categroy vectors to labels
y_pred = np.argmax(y_pred, axis=1)

# plotting
plt.figure(figsize=(14,5))

# plt y_test
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, color='green', label='y_test')

# plt y_pred
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred, color='blue', label='predictions')

plt.legend()
plt.title('MLP prediction with Standard Scaler')
plt.show()
# Out:
# 24/24 [==============================] - 0s 3ms/step

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 338.621719552139

# %%
# OLS Model using Standard Scaler:


# Add a constant to the features
X_train_scaled_sm = sm.add_constant(X_train_scaled)
X_test_scaled_sm = sm.add_constant(X_test_scaled)

# Train the model
model = sm.OLS(y_train, X_train_scaled_sm)
results = model.fit()

# Now you can use the results object to make predictions
y_pred = results.predict(X_test_scaled_sm)

# Plotting the results
plt.figure(figsize=(14,5))

# Plotting the y_train
#plt.plot(range(len(y_train)), y_train, color='blue', label='y_train')

# Plotting the y_test
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, color='green', label='y_test')

# Plotting the predictions
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred, color='blue', label='predictions')

plt.legend()
plt.title('OLS Model prediction with Standard Scaler')
plt.show()
# Out:
# C:\Apps\anaconda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 300.3546022247436

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from keras.utils import to_categorical

# define your set of parameters
optimizers = [SGD, Adam, RMSprop]
learning_rates = [0.01, 0.001, 0.0001]
hidden_layers = [2, 3, 4]
epochs = [20, 30, 50]

best_score = 0
best_params = {}

for opt in optimizers:
    for lr in learning_rates:
        for layers in hidden_layers:
            for epoch in epochs:
                print(f"Training with optimizer={opt}, learning_rate={lr}, hidden_layers={layers}, epochs={epoch}")

                model = Sequential()

                # Input layer
                model.add(Dense(32, activation='relu', input_shape=(5,)))

                # Hidden layers
                for _ in range(layers):
                    model.add(Dense(64, activation='relu'))

                # Output layer
                model.add(Dense(num_classes, activation='softmax'))

                # compile the model
                model.compile(loss='categorical_crossentropy',
                              optimizer=opt(learning_rate=lr),  
                              metrics=['accuracy'])

                # fit the model to the training data
                model.fit(X_train_scaled, y_train_categorical, epochs=epoch, batch_size=32)

                # evaluate the model on the test data
                score = model.evaluate(X_test_scaled, y_test_categorical)

                print(f"Score: {score[1]}")  # Use score[1] to access accuracy
                
                if score[1] > best_score:   # Compare the accuracy, not the entire list
                    best_score = score[1]
                    best_params = {"optimizer": opt, "learning_rate": lr, "hidden_layers": layers, "epochs": epoch}

print(f"Best score: {best_score} with parameters {best_params}")
# Out:
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=2, epochs=20
# Epoch 1/20
# 445/445 [==============================] - 2s 4ms/step - loss: 7.8312 - accuracy: 0.1251
# Epoch 2/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.8119 - accuracy: 0.1283
# Epoch 3/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.3625 - accuracy: 0.1423
# Epoch 4/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.1697 - accuracy: 0.1550
# Epoch 5/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.0203 - accuracy: 0.1721
# Epoch 6/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.9196 - accuracy: 0.1841
# Epoch 7/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.8546 - accuracy: 0.1917
# Epoch 8/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.8087 - accuracy: 0.1941
# Epoch 9/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7708 - accuracy: 0.1975
# Epoch 10/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7413 - accuracy: 0.1992
# Epoch 11/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7157 - accuracy: 0.2030
# Epoch 12/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7007 - accuracy: 0.2020
# Epoch 13/20
# 445/445 [==============================] - 4s 8ms/step - loss: 2.6843 - accuracy: 0.2063
# Epoch 14/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6770 - accuracy: 0.1993
# Epoch 15/20
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6636 - accuracy: 0.2062
# Epoch 16/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6537 - accuracy: 0.2056
# Epoch 17/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6465 - accuracy: 0.2093
# Epoch 18/20
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6380 - accuracy: 0.2088
# Epoch 19/20
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6314 - accuracy: 0.2119
# Epoch 20/20
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6259 - accuracy: 0.2098
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6339 - accuracy: 0.2072
# Score: 0.20721925795078278
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=2, epochs=30
# Epoch 1/30
# 445/445 [==============================] - 2s 4ms/step - loss: 7.0518 - accuracy: 0.1222
# Epoch 2/30
# 445/445 [==============================] - 2s 5ms/step - loss: 3.6305 - accuracy: 0.1364
# Epoch 3/30
# 445/445 [==============================] - 3s 6ms/step - loss: 3.3185 - accuracy: 0.1403
# Epoch 4/30
# 445/445 [==============================] - 2s 5ms/step - loss: 3.1524 - accuracy: 0.1568
# Epoch 5/30
# 445/445 [==============================] - 2s 5ms/step - loss: 3.0107 - accuracy: 0.1696
# Epoch 6/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.9092 - accuracy: 0.1847
# Epoch 7/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.8378 - accuracy: 0.1952
# Epoch 8/30
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7892 - accuracy: 0.1998
# Epoch 9/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7545 - accuracy: 0.2030
# Epoch 10/30
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7324 - accuracy: 0.1995
# Epoch 11/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7112 - accuracy: 0.2036
# Epoch 12/30
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6933 - accuracy: 0.2083
# Epoch 13/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6835 - accuracy: 0.2037
# Epoch 14/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6721 - accuracy: 0.2072
# Epoch 15/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6596 - accuracy: 0.2073
# Epoch 16/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6542 - accuracy: 0.2061
# Epoch 17/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6468 - accuracy: 0.2093
# Epoch 18/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6381 - accuracy: 0.2107
# Epoch 19/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6338 - accuracy: 0.2098
# Epoch 20/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6277 - accuracy: 0.2135
# Epoch 21/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6200 - accuracy: 0.2122
# Epoch 22/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6151 - accuracy: 0.2124
# Epoch 23/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6110 - accuracy: 0.2111
# Epoch 24/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6049 - accuracy: 0.2128
# Epoch 25/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6014 - accuracy: 0.2110
# Epoch 26/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5952 - accuracy: 0.2161
# Epoch 27/30
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5914 - accuracy: 0.2159
# Epoch 28/30
# 445/445 [==============================] - 2s 6ms/step - loss: 2.5899 - accuracy: 0.2131
# Epoch 29/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.5848 - accuracy: 0.2161
# Epoch 30/30
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5801 - accuracy: 0.2183
# 24/24 [==============================] - 0s 3ms/step - loss: 2.7519 - accuracy: 0.2019
# Score: 0.20187166333198547
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=2, epochs=50
# Epoch 1/50
# 445/445 [==============================] - 2s 4ms/step - loss: 8.2783 - accuracy: 0.1238
# Epoch 2/50
# 445/445 [==============================] - 2s 5ms/step - loss: 4.0692 - accuracy: 0.1392
# Epoch 3/50
# 445/445 [==============================] - 3s 6ms/step - loss: 3.3466 - accuracy: 0.1523
# Epoch 4/50
# 445/445 [==============================] - 3s 6ms/step - loss: 3.1557 - accuracy: 0.1625
# Epoch 5/50
# 445/445 [==============================] - 2s 5ms/step - loss: 3.0139 - accuracy: 0.1746
# Epoch 6/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.9199 - accuracy: 0.1879
# Epoch 7/50
# 445/445 [==============================] - 3s 7ms/step - loss: 2.8535 - accuracy: 0.1955
# Epoch 8/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.8118 - accuracy: 0.1957
# Epoch 9/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7755 - accuracy: 0.1994
# Epoch 10/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7512 - accuracy: 0.1995
# Epoch 11/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7291 - accuracy: 0.2034
# Epoch 12/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7113 - accuracy: 0.2067
# Epoch 13/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.7004 - accuracy: 0.2030
# Epoch 14/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6875 - accuracy: 0.2009
# Epoch 15/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6754 - accuracy: 0.2040
# Epoch 16/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6660 - accuracy: 0.2021
# Epoch 17/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6571 - accuracy: 0.2095
# Epoch 18/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6500 - accuracy: 0.2031
# Epoch 19/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6442 - accuracy: 0.2076
# Epoch 20/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6388 - accuracy: 0.2098
# Epoch 21/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6288 - accuracy: 0.2107
# Epoch 22/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6231 - accuracy: 0.2160
# Epoch 23/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6158 - accuracy: 0.2184
# Epoch 24/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6138 - accuracy: 0.2110
# Epoch 25/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6088 - accuracy: 0.2150
# Epoch 26/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6027 - accuracy: 0.2126
# Epoch 27/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.6008 - accuracy: 0.2155
# Epoch 28/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5953 - accuracy: 0.2152
# Epoch 29/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5940 - accuracy: 0.2169
# Epoch 30/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5880 - accuracy: 0.2175
# Epoch 31/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5840 - accuracy: 0.2150
# Epoch 32/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5830 - accuracy: 0.2150
# Epoch 33/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5786 - accuracy: 0.2195
# Epoch 34/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5783 - accuracy: 0.2169
# Epoch 35/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5744 - accuracy: 0.2171
# Epoch 36/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5717 - accuracy: 0.2224
# Epoch 37/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5672 - accuracy: 0.2223
# Epoch 38/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5683 - accuracy: 0.2162
# Epoch 39/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5641 - accuracy: 0.2166
# Epoch 40/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5608 - accuracy: 0.2193
# Epoch 41/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5592 - accuracy: 0.2199
# Epoch 42/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5572 - accuracy: 0.2218
# Epoch 43/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5563 - accuracy: 0.2184
# Epoch 44/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5516 - accuracy: 0.2254
# Epoch 45/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5502 - accuracy: 0.2202
# Epoch 46/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5465 - accuracy: 0.2254
# Epoch 47/50
# 445/445 [==============================] - 2s 4ms/step - loss: 2.5458 - accuracy: 0.2259
# Epoch 48/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5447 - accuracy: 0.2180
# Epoch 49/50
# 445/445 [==============================] - 2s 5ms/step - loss: 2.5410 - accuracy: 0.2220
# Epoch 50/50
# 445/445 [==============================] - 3s 6ms/step - loss: 2.5415 - accuracy: 0.2205
# 24/24 [==============================] - 0s 4ms/step - loss: 2.6259 - accuracy: 0.2179
# Score: 0.2179144322872162
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=3, epochs=20
# Epoch 1/20
# 445/445 [==============================] - 3s 5ms/step - loss: 7.5978 - accuracy: 0.1275
# Epoch 2/20
# 445/445 [==============================] - 3s 6ms/step - loss: 3.6047 - accuracy: 0.1290
# Epoch 3/20
# 445/445 [==============================] - 3s 6ms/step - loss: 3.3346 - accuracy: 0.1375
# Epoch 4/20
# 445/445 [==============================] - 3s 7ms/step - loss: 3.1314 - accuracy: 0.1625
# Epoch 5/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.9643 - accuracy: 0.1749
# Epoch 6/20
# 445/445 [==============================] - 2s 5ms/step - loss: 2.8675 - accuracy: 0.1832
# Epoch 7/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.8070 - accuracy: 0.1912
# Epoch 8/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.7709 - accuracy: 0.1919
# Epoch 9/20
# 445/445 [==============================] - 3s 8ms/step - loss: 2.7407 - accuracy: 0.1918
# Epoch 10/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.7209 - accuracy: 0.1913
# Epoch 11/20
# 445/445 [==============================] - 6s 14ms/step - loss: 2.7002 - accuracy: 0.1965
# 445/445 [==============================] - 7s 16ms/step - loss: 2.5227 - accuracy: 0.2241
# Epoch 50/50
# 445/445 [==============================] - 7s 16ms/step - loss: 2.5189 - accuracy: 0.2269
# 24/24 [==============================] - 1s 13ms/step - loss: 2.6314 - accuracy: 0.2059
# Score: 0.20588235557079315
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=4, epochs=20
# Epoch 1/20
# 445/445 [==============================] - 8s 12ms/step - loss: 7.9284 - accuracy: 0.1220
# Epoch 2/20
# 445/445 [==============================] - 2s 5ms/step - loss: 3.6003 - accuracy: 0.1198
# Epoch 3/20
# 445/445 [==============================] - 3s 7ms/step - loss: 3.4042 - accuracy: 0.1193
# Epoch 4/20
# 445/445 [==============================] - 3s 7ms/step - loss: 3.2742 - accuracy: 0.1436
# Epoch 5/20
# 445/445 [==============================] - 3s 6ms/step - loss: 3.0994 - accuracy: 0.1606
# Epoch 6/20
# 445/445 [==============================] - 5s 11ms/step - loss: 2.9251 - accuracy: 0.1673
# Epoch 7/20
# 445/445 [==============================] - 5s 12ms/step - loss: 2.8292 - accuracy: 0.1825
# Epoch 8/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7782 - accuracy: 0.1911
# Epoch 9/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.7454 - accuracy: 0.1898
# Epoch 10/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.7216 - accuracy: 0.1978
# Epoch 11/20
# 445/445 [==============================] - 4s 10ms/step - loss: 2.7053 - accuracy: 0.2009
# Epoch 12/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6904 - accuracy: 0.2013
# Epoch 13/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6761 - accuracy: 0.2005
# Epoch 14/20
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6629 - accuracy: 0.2051
# Epoch 15/20
# 445/445 [==============================] - 4s 9ms/step - loss: 2.6546 - accuracy: 0.2052
# Epoch 16/20
# 445/445 [==============================] - 3s 6ms/step - loss: 2.6463 - accuracy: 0.2005
# Epoch 17/20
# 445/445 [==============================] - 5s 11ms/step - loss: 2.6366 - accuracy: 0.2076
# Epoch 18/20
# 445/445 [==============================] - 7s 16ms/step - loss: 2.6270 - accuracy: 0.2094
# Epoch 19/20
# 445/445 [==============================] - 7s 15ms/step - loss: 2.6207 - accuracy: 0.2100
# Epoch 20/20
# 445/445 [==============================] - 4s 10ms/step - loss: 2.6124 - accuracy: 0.2121
# 24/24 [==============================] - 0s 5ms/step - loss: 2.6361 - accuracy: 0.2473
# Score: 0.24732621014118195
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=4, epochs=30
# Epoch 1/30
# 445/445 [==============================] - 3s 6ms/step - loss: 8.6283 - accuracy: 0.1256
# Epoch 2/30
# 445/445 [==============================] - 2s 6ms/step - loss: 4.1032 - accuracy: 0.1231
# Epoch 3/30
# 445/445 [==============================] - 3s 7ms/step - loss: 3.4041 - accuracy: 0.1255
# Epoch 4/30
# 445/445 [==============================] - 3s 8ms/step - loss: 3.2347 - accuracy: 0.1324
# Epoch 5/30
# 445/445 [==============================] - 4s 8ms/step - loss: 3.0126 - accuracy: 0.1626
# Epoch 6/30
# 445/445 [==============================] - 5s 10ms/step - loss: 2.8888 - accuracy: 0.1790
# Epoch 7/30
# 445/445 [==============================] - 7s 15ms/step - loss: 2.8143 - accuracy: 0.1855
# Epoch 8/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.7655 - accuracy: 0.1903
# Epoch 9/30
# 445/445 [==============================] - 4s 8ms/step - loss: 2.7315 - accuracy: 0.1945
# Epoch 10/30
# 445/445 [==============================] - 3s 8ms/step - loss: 2.7054 - accuracy: 0.1939
# Epoch 11/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6864 - accuracy: 0.2003
# Epoch 12/30
# 445/445 [==============================] - 4s 8ms/step - loss: 2.6697 - accuracy: 0.2008
# Epoch 13/30
# 445/445 [==============================] - 7s 15ms/step - loss: 2.6574 - accuracy: 0.2015
# Epoch 14/30
# 445/445 [==============================] - 7s 15ms/step - loss: 2.6467 - accuracy: 0.2043
# Epoch 15/30
# 445/445 [==============================] - 6s 14ms/step - loss: 2.6371 - accuracy: 0.2049
# Epoch 16/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6264 - accuracy: 0.2122
# Epoch 17/30
# 445/445 [==============================] - 3s 8ms/step - loss: 2.6224 - accuracy: 0.2109
# Epoch 18/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.6139 - accuracy: 0.2086
# Epoch 19/30
# 445/445 [==============================] - 4s 8ms/step - loss: 2.6083 - accuracy: 0.2102
# Epoch 20/30
# 445/445 [==============================] - 7s 17ms/step - loss: 2.5983 - accuracy: 0.2106
# Epoch 21/30
# 445/445 [==============================] - 8s 17ms/step - loss: 2.5956 - accuracy: 0.2053
# Epoch 22/30
# 445/445 [==============================] - 6s 13ms/step - loss: 2.5877 - accuracy: 0.2081
# Epoch 23/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.5785 - accuracy: 0.2089
# Epoch 24/30
# 445/445 [==============================] - 3s 8ms/step - loss: 2.5740 - accuracy: 0.2149
# Epoch 25/30
# 445/445 [==============================] - 4s 9ms/step - loss: 2.5680 - accuracy: 0.2156
# Epoch 26/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.5626 - accuracy: 0.2156
# Epoch 27/30
# 445/445 [==============================] - 3s 7ms/step - loss: 2.5559 - accuracy: 0.2194
# Epoch 28/30
# 445/445 [==============================] - 4s 8ms/step - loss: 2.5500 - accuracy: 0.2184
# Epoch 29/30
# 445/445 [==============================] - 3s 8ms/step - loss: 2.5461 - accuracy: 0.2155
# Epoch 30/30
# 445/445 [==============================] - 5s 11ms/step - loss: 2.5401 - accuracy: 0.2191
# 24/24 [==============================] - 1s 11ms/step - loss: 2.6938 - accuracy: 0.2032
# Score: 0.2032085508108139
# Training with optimizer=<class 'keras.optimizers.sgd.SGD'>, learning_rate=0.01, hidden_layers=4, epochs=50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26156/1986974783.py in <module>
#      37
#      38                 # fit the model to the training data
# ---> 39                 model.fit(X_train_scaled, y_train_categorical, epochs=epoch, batch_size=32)
#      40
#      41                 # evaluate the model on the test data
#
# C:\Apps\anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Apps\anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# C:\Apps\anaconda\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
best_score
# Out:
# 0.24732621014118195

# %%
best_params
# Out:
# {'optimizer': keras.optimizers.sgd.SGD,
#  'learning_rate': 0.01,
#  'hidden_layers': 4,
#  'epochs': 20}

# %%
# standardize by X data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)
X_test_scaled

# number of classes:
num_classes = 7101

# one-hot vectors
y_train_categorical = to_categorical(y_train, num_classes=num_classes)
y_test_categorical = to_categorical(y_test, num_classes=num_classes)

model = Sequential()

# Input layer
model.add(Dense(32, activation='relu', input_shape=(5,)))

# Hidden layers
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output layer
model.add(Dense(num_classes, activation='softmax'))

# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01),  # note the change to `learning_rate` from `lr`
              metrics=['accuracy'])

# fit the model to the training data
model.fit(X_train_scaled, y_train_categorical, epochs=20, batch_size=32)

# predict using my model
y_pred = model.predict(X_test_scaled)

# turn categroy vectors to labels
y_pred = np.argmax(y_pred, axis=1)

# plotting
plt.figure(figsize=(14,5))

# plt y_test
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, color='green', label='y_test')

# plt y_pred
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred, color='blue', label='predictions')

plt.legend()
plt.title('MLP prediction with Standard Scaler After selection')
plt.show()
# Out:
# Epoch 1/20
# 445/445 [==============================] - 2s 4ms/step - loss: 7.6539 - accuracy: 0.1224
# Epoch 2/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.5558 - accuracy: 0.1231
# Epoch 3/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.3492 - accuracy: 0.1348
# Epoch 4/20
# 445/445 [==============================] - 2s 4ms/step - loss: 3.1854 - accuracy: 0.1533
# Epoch 5/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.9955 - accuracy: 0.1667
# Epoch 6/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.8736 - accuracy: 0.1796
# Epoch 7/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.8028 - accuracy: 0.1901
# Epoch 8/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7676 - accuracy: 0.1918
# Epoch 9/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7388 - accuracy: 0.1961
# Epoch 10/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.7179 - accuracy: 0.2003
# Epoch 11/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6997 - accuracy: 0.1981
# Epoch 12/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6836 - accuracy: 0.2025
# Epoch 13/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6687 - accuracy: 0.2058
# Epoch 14/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6593 - accuracy: 0.2033
# Epoch 15/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6484 - accuracy: 0.2057
# Epoch 16/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6381 - accuracy: 0.2124
# Epoch 17/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6301 - accuracy: 0.2080
# Epoch 18/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6204 - accuracy: 0.2102
# Epoch 19/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6155 - accuracy: 0.2095
# Epoch 20/20
# 445/445 [==============================] - 2s 4ms/step - loss: 2.6076 - accuracy: 0.2117
# 24/24 [==============================] - 0s 3ms/step
